# %% [markdown]
# Import the libraries.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Create the dataframe.

# %%
df = pd.DataFrame([[8,8,1],[7,9,1],[6,10,0],[5,5,0]], columns=['cgpa', 'profile_score', 'placed'])
df
# Out:
#    cgpa  profile_score  placed
# 0     8              8       1
# 1     7              9       1
# 2     6             10       0
# 3     5              5       0

# %% [markdown]
# Funcion to define parameters.

# %%
def init_params(layer_dim):
    np.random.seed(3)
    parameters ={}
    L = len(layer_dim)
    
    for l in range(1,L):
        
        parameters['W' + str(l)] = np.ones((layer_dim[l-1], layer_dim[l]))*0.1
        parameters['b' + str(l)] = np.zeros((layer_dim[l], 1))
    
    return parameters

# %% [markdown]
# Sigmoid function as  activation function for clasification problem.

# %%
def sigmoid(Z):
  
  A = 1/(1+np.exp(-Z))

  return A

# %% [markdown]
# Function to perform forward pass for one neural network layer.

# %%
def linear_forward(A_prev, W, b):
  
  Z = np.dot(W.T, A_prev) + b

  A = sigmoid(Z)
  
  return A

# %% [markdown]
# Function to perform forward propogation.

# %%
def forward_propagation(X, parameters):
    
    A = X
    L = len(parameters) // 2
    
    for l in range(1,L+1):
        A_prev = A
        Wl = parameters['W' + str(l)]
        bl = parameters['b' + str(l)]
        print("A"+str(l-1)+": ", A_prev)
        print("W"+str(l)+": ", Wl)
        print("b"+str(l)+": ", bl)
        print("--"*20)

        A = linear_forward(A_prev, Wl, bl)
        print("A"+str(l)+": ", A)
        print("**"*20)
    
    return A, A_prev

# %% [markdown]
# Function to update the parameters.

# %%
def update_parameters(parameters,y,y_hat,A1,X):
  parameters['W2'][0][0] = parameters['W2'][0][0] + (0.0001 * (y - y_hat)*A1[0][0])
  parameters['W2'][1][0] = parameters['W2'][1][0] + (0.0001 * (y - y_hat)*A1[1][0])
  parameters['b2'][0][0] = parameters['b2'][0][0] + (0.0001 * (y - y_hat))

  parameters['W1'][0][0] = parameters['W1'][0][0] + (0.0001 * (y - y_hat)*parameters['W2'][0][0]*A1[0][0]*(1-A1[0][0])*X[0][0])
  parameters['W1'][0][1] = parameters['W1'][0][1] + (0.0001 * (y - y_hat)*parameters['W2'][0][0]*A1[0][0]*(1-A1[0][0])*X[1][0])
  parameters['b1'][0][0] = parameters['b1'][0][0] + (0.0001 * (y - y_hat)*parameters['W2'][0][0]*A1[0][0]*(1-A1[0][0]))

  parameters['W1'][1][0] = parameters['W1'][1][0] + (0.0001 * (y - y_hat)*parameters['W2'][1][0]*A1[1][0]*(1-A1[1][0])*X[0][0])
  parameters['W1'][1][1] = parameters['W1'][1][1] + (0.0001 * (y - y_hat)*parameters['W2'][1][0]*A1[1][0]*(1-A1[1][0])*X[1][0])
  parameters['b1'][1][0] = parameters['b1'][1][0] + (0.0001 * (y - y_hat)*parameters['W2'][1][0]*A1[1][0]*(1-A1[1][0]))

# %% [markdown]
# Find y_hat for point of x coresponding loss and update the parameters.

# %%
X = df[['cgpa', 'profile_score']].values[0].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['placed']].values[0][0]

# Parameter initialization
parameters = init_params([2,2,1])

y_hat,A1 = forward_propagation(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

print('Loss for this student - ',-y*np.log(y_hat) - (1-y)*np.log(1-y_hat))

parameters
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[0.83201839]
#  [0.83201839]]
# ****************************************
# A1:  [[0.83201839]
#  [0.83201839]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.54150519]]
# ****************************************
# Loss for this student -  0.613402628898913
# {'W1': array([[0.10000513, 0.10000513],
#         [0.10000513, 0.10000513]]),
#  'b1': array([[6.41054186e-07],
#         [6.41054186e-07]]),
#  'W2': array([[0.10003815],
#         [0.10003815]]),
#  'b2': array([[4.5849481e-05]])}

# %%
X = df[['cgpa', 'profile_score']].values[1].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['placed']].values[1][0]

y_hat,A1 = forward_propagation(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

print('Loss for this student - ',-y*np.log(y_hat) - (1-y)*np.log(1-y_hat))

parameters
# Out:
# A0:  [[7]
#  [9]]
# W1:  [[0.10000513 0.10000513]
#  [0.10000513 0.10000513]]
# b1:  [[6.41054186e-07]
#  [6.41054186e-07]]
# ----------------------------------------
# A1:  [[0.83202994]
#  [0.83202994]]
# ****************************************
# A1:  [[0.83202994]
#  [0.83202994]]
# W2:  [[0.10003815]
#  [0.10003815]]
# b2:  [[4.5849481e-05]]
# ----------------------------------------
# A2:  [[0.54153291]]
# ****************************************
# Loss for this student -  0.6133514436691428
# {'W1': array([[0.10000962, 0.1000109 ],
#         [0.10000962, 0.1000109 ]]),
#  'b1': array([[1.28227883e-06],
#         [1.28227883e-06]]),
#  'W2': array([[0.10007629],
#         [0.10007629]]),
#  'b2': array([[9.16961903e-05]])}

# %%
X = df[['cgpa', 'profile_score']].values[2].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['placed']].values[2][0]

y_hat,A1 = forward_propagation(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

print('Loss for this student - ',-y*np.log(y_hat) - (1-y)*np.log(1-y_hat))

parameters
# Out:
# A0:  [[ 6]
#  [10]]
# W1:  [[0.10000962 0.1000109 ]
#  [0.10000962 0.1000109 ]]
# b1:  [[1.28227883e-06]
#  [1.28227883e-06]]
# ----------------------------------------
# A1:  [[0.83204007]
#  [0.83204294]]
# ****************************************
# A1:  [[0.83204007]
#  [0.83204294]]
# W2:  [[0.10007629]
#  [0.10007629]]
# b2:  [[9.16961903e-05]]
# ----------------------------------------
# A2:  [[0.54156062]]
# ****************************************
# Loss for this student -  0.7799272184937318
# {'W1': array([[0.10000507, 0.10000333],
#         [0.10000507, 0.10000333]]),
#  'b1': array([[5.25214767e-07],
#         [5.25225084e-07]]),
#  'W2': array([[0.10003123],
#         [0.10003123]]),
#  'b2': array([[3.75401279e-05]])}

# %% [markdown]
# Repeat the process for epochs and print the loss.

# %%
parameters = init_params([2,2,1])
epochs = 75

for i in range(epochs):

  Loss = []

  for j in range(df.shape[0]):

    X = df[['cgpa', 'profile_score']].values[j].reshape(2,1) # Shape(no of features, no. of training example)
    y = df[['placed']].values[j][0]

    # Parameter initialization


    y_hat,A1 = forward_propagation(X,parameters)
    y_hat = y_hat[0][0]

    update_parameters(parameters,y,y_hat,A1,X)

    Loss.append(-y*np.log(y_hat) - (1-y)*np.log(1-y_hat))

  print('Epoch - ',i+1,'Loss - ',np.array(Loss).mean())
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[0.83201839]
#  [0.83201839]]
# ****************************************
# A1:  [[0.83201839]
#  [0.83201839]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.54150519]]
# ****************************************
# A0:  [[7]
#  [9]]
# W1:  [[0.10000513 0.10000513]
#  [0.10000513 0.10000513]]
# b1:  [[6.41054186e-07]
#  [6.41054186e-07]]
# ----------------------------------------
# A1:  [[0.83202994]
#  [0.83202994]]
# ****************************************
# A1:  [[0.83202994]
#  [0.83202994]]
# W2:  [[0.10003815]
#  [0.10003815]]
# b2:  [[4.5849481e-05]]
# ----------------------------------------
# A2:  [[0.54153291]]
# ****************************************
# A0:  [[ 6]
#  [10]]
# W1:  [[0.10000962 0.1000109 ]
#  [0.10000962 0.1000109 ]]
# b1:  [[1.28227883e-06]
#  [1.28227883e-06]]
# ...

# %% [markdown]
# Doing the same thing with tenserflow's functions.

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %% [markdown]
# Make neural network layers.

# %%
model = Sequential()

model.add(Dense(2, input_dim=2, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# /home/hardik/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
# ...

# %% [markdown]
# Get the default weights of the model.

# %%
model.get_weights
# Out:
# <bound method Layer.get_weights of <Sequential name=sequential_1, built=True>>

# %% [markdown]
# Set the weights to same as self initialized one.

# %%
weights = [np.array([[0.1, 0.1], [0.1, 0.1]], dtype=np.float32), 
           np.array([0., 0.], dtype=np.float32), 
           np.array([[0.1], [0.1]], dtype=np.float32), 
           np.array([0.], dtype=np.float32)]

model.set_weights(weights)

# %% [markdown]
# Set the lr of optimizer as same as self made and compile the model.

# %%
optimizer = keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer)

# %% [markdown]
# Train the model and print the loss.

# %%
model.fit(df[['cgpa', 'profile_score']].values, df[['placed']].values, epochs=50, verbose=1, batch_size=1)
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6942
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6942
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6942
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6941
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6941
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6941
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6941
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6941
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6941
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6941
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6941
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.6941
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6941
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6940
# Epoch 15/50
# ...
